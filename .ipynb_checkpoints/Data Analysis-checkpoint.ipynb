# %% [markdown]
# # Reading Regression Timing Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df = pd.read_csv('regression_timings master list.csv')
df
# Out:
#                                                Test Name  MyISAM Total Time  \
# 0      Cloud/configuration/cloud_avg_cores_reserved/a...           0.059955
# 1      Cloud/configuration/cloud_avg_cores_reserved/a...           0.065416
# 2      Cloud/configuration/cloud_avg_cores_reserved/a...           0.072476
# 3      Cloud/configuration/cloud_avg_cores_reserved/a...           0.063708
# 4      Cloud/configuration/cloud_avg_cores_reserved/a...           0.064494
# ...                                                  ...                ...
# 24395     Storage/username/user_count/timeseries-Year-cd           0.496918
# 24396     Storage/username/user_count/timeseries-Year-cs           0.495570
# 24397     Storage/username/user_count/timeseries-Year-pi           0.068550
# 24398  Storage/username/user_count/timeseries-Year-pu...           0.045511
# 24399    Storage/username/user_count/timeseries-Year-usr           0.071226
#
#        MyISAM Start Transfer Time  Unnamed: 3  InnoDB Total Time  \
# 0                        0.059950         NaN           0.056255
# 1                        0.065412         NaN           0.061219
# 2                        0.072471         NaN           0.065990
# 3                        0.063705         NaN           0.056681
# 4                        0.064490         NaN           0.062833
# ...                           ...         ...                ...
# 24395                    0.492954         NaN           0.244348
# 24396                    0.490856         NaN           0.261630
# 24397                    0.068547         NaN           0.062513
# 24398                    0.045504         NaN           0.048143
# 24399                    0.071222         NaN           0.068632
#
#        InnoDB Start Transfer Time
# 0                        0.056252
# 1                        0.061216
# 2                        0.065987
# 3                        0.056678
# 4                        0.062812
# ...                           ...
# 24395                    0.240255
# 24396                    0.256816
# 24397                    0.062508
# 24398                    0.048140
# 24399                    0.068628
#
# [24400 rows x 6 columns]

# %% [markdown]
# # Charting Total and Transfer Times

# %%
#df.sum() #sums all cols by default
cols_to_sum = ['MyISAM Total Time','MyISAM Start Transfer Time','InnoDB Total Time','InnoDB Start Transfer Time']
total_time = df[cols_to_sum].sum()
print(total_time)
plt.title("Regression Timings: MyISAM vs InnoDB")
#plt.bar(cols_to_sum, total_time)
plt.bar(cols_to_sum[0], total_time[0], color='blue', label='MyISAM')
plt.bar(cols_to_sum[2], total_time[2], color='red', label='InnoDB')
plt.bar(cols_to_sum[1], total_time[1], color='blue')
plt.bar(cols_to_sum[3], total_time[3], color='red')
plt.xticks(rotation=90) #rotate lables vertically
plt.xlabel('Database Timings')
plt.ylabel('Total Time Take (seconds)')
plt.legend()
plt.show()
# Out:
# MyISAM Total Time             8013.868693
# MyISAM Start Transfer Time    8004.468570
# InnoDB Total Time             4517.444272
# InnoDB Start Transfer Time    4508.897521
# dtype: float64

# %% [markdown]
# # Modifying Dataframe

# %%
del df['Unnamed: 3'] #Get rid of blank column, no need to rerun this whole block (errors)
df.insert(1, 'Realm', '')
df.insert(2, 'Group By', '')
df.insert(3, 'Statistic', '')
df.insert(4, 'Data Set Type', '')
df.insert(5, 'Aggregation Unit', '')
df
# Out:
#                                                Test Name Realm Group By  \
# 0      Cloud/configuration/cloud_avg_cores_reserved/a...
# 1      Cloud/configuration/cloud_avg_cores_reserved/a...
# 2      Cloud/configuration/cloud_avg_cores_reserved/a...
# 3      Cloud/configuration/cloud_avg_cores_reserved/a...
# 4      Cloud/configuration/cloud_avg_cores_reserved/a...
# ...                                                  ...   ...      ...
# 24395     Storage/username/user_count/timeseries-Year-cd
# 24396     Storage/username/user_count/timeseries-Year-cs
# 24397     Storage/username/user_count/timeseries-Year-pi
# 24398  Storage/username/user_count/timeseries-Year-pu...
# 24399    Storage/username/user_count/timeseries-Year-usr
#
#       Statistic Data Set Type Aggregation Unit  MyISAM Total Time  \
# 0                                                        0.059955
# 1                                                        0.065416
# 2                                                        0.072476
# 3                                                        0.063708
# 4                                                        0.064494
# ...         ...           ...              ...                ...
# 24395                                                    0.496918
# 24396                                                    0.495570
# 24397                                                    0.068550
# 24398                                                    0.045511
# 24399                                                    0.071226
#
#        MyISAM Start Transfer Time  InnoDB Total Time  \
# 0                        0.059950           0.056255
# 1                        0.065412           0.061219
# 2                        0.072471           0.065990
# 3                        0.063705           0.056681
# 4                        0.064490           0.062833
# ...                           ...                ...
# 24395                    0.492954           0.244348
# 24396                    0.490856           0.261630
# 24397                    0.068547           0.062513
# 24398                    0.045504           0.048143
# 24399                    0.071222           0.068632
#
#        InnoDB Start Transfer Time
# 0                        0.056252
# 1                        0.061216
# 2                        0.065987
# 3                        0.056678
# 4                        0.062812
# ...                           ...
# 24395                    0.240255
# 24396                    0.256816
# 24397                    0.062508
# 24398                    0.048140
# 24399                    0.068628
#
# [24400 rows x 10 columns]

# %% [markdown]
# # Splitting & Inserting Test Names

# %%
pd.options.mode.chained_assignment = None  # default='warn'
import re # regex required for multiple special cases
for i in range(len(df['Test Name'])):
    temp = re.split('/|-', df['Test Name'][i])
    df['Realm'][i] = temp[0] 
    df['Group By'][i] = temp[1]
    df['Statistic'][i] = temp[2]
    df['Data Set Type'][i] = temp[3]
    df['Aggregation Unit'][i] = temp[4] #Do not believe we need temp[5] otherwise concatenate
df

# %% [markdown]
# # Further Analysis

# %% [markdown]
# ## Percentages

# %% [markdown]
# ### Calculating Percentages Into A New Dataframe

# %%
perc_df = df
calc_perc = (100. * df[cols_to_sum] / df[cols_to_sum].sum()).round(4).astype(str) + '%'
perc_df.update(calc_perc)
perc_df
# Out:
#                                                Test Name    Realm  \
# 0      Cloud/configuration/cloud_avg_cores_reserved/a...    Cloud
# 1      Cloud/configuration/cloud_avg_cores_reserved/a...    Cloud
# 2      Cloud/configuration/cloud_avg_cores_reserved/a...    Cloud
# 3      Cloud/configuration/cloud_avg_cores_reserved/a...    Cloud
# 4      Cloud/configuration/cloud_avg_cores_reserved/a...    Cloud
# ...                                                  ...      ...
# 24395     Storage/username/user_count/timeseries-Year-cd  Storage
# 24396     Storage/username/user_count/timeseries-Year-cs  Storage
# 24397     Storage/username/user_count/timeseries-Year-pi  Storage
# 24398  Storage/username/user_count/timeseries-Year-pu...  Storage
# 24399    Storage/username/user_count/timeseries-Year-usr  Storage
#
#             Group By                 Statistic Data Set Type Aggregation Unit  \
# 0      configuration  cloud_avg_cores_reserved     aggregate              Day
# 1      configuration  cloud_avg_cores_reserved     aggregate              Day
# 2      configuration  cloud_avg_cores_reserved     aggregate              Day
# 3      configuration  cloud_avg_cores_reserved     aggregate              Day
# 4      configuration  cloud_avg_cores_reserved     aggregate              Day
# ...              ...                       ...           ...              ...
# 24395       username                user_count    timeseries             Year
# 24396       username                user_count    timeseries             Year
# 24397       username                user_count    timeseries             Year
# 24398       username                user_count    timeseries             Year
# 24399       username                user_count    timeseries             Year
#
#       MyISAM Total Time MyISAM Start Transfer Time InnoDB Total Time  \
# 0               0.0007%                    0.0007%           0.0012%
# 1               0.0008%                    0.0008%           0.0014%
# 2               0.0009%                    0.0009%           0.0015%
# 3               0.0008%                    0.0008%           0.0013%
# 4               0.0008%                    0.0008%           0.0014%
# ...                 ...                        ...               ...
# 24395           0.0062%                    0.0062%           0.0054%
# 24396           0.0062%                    0.0061%           0.0058%
# 24397           0.0009%                    0.0009%           0.0014%
# 24398           0.0006%                    0.0006%           0.0011%
# 24399           0.0009%                    0.0009%           0.0015%
#
#       InnoDB Start Transfer Time
# 0                        0.0012%
# 1                        0.0014%
# 2                        0.0015%
# 3                        0.0013%
# 4                        0.0014%
# ...                          ...
# 24395                    0.0053%
# 24396                    0.0057%
# 24397                    0.0014%
# 24398                    0.0011%
# 24399                    0.0015%
#
# [24400 rows x 10 columns]

# %% [markdown]
# ## Specific Tests

# %%
df.groupby('Realm').sum()
# Out:
#          MyISAM Total Time  MyISAM Start Transfer Time  InnoDB Total Time  \
# Realm
# Cloud           389.276439                  389.242494         378.858606
# Jobs           6765.682096                 6759.907872        3741.940596
# Storage         858.910158                  855.318204         396.645070
#
#          InnoDB Start Transfer Time
# Realm
# Cloud                    378.828317
# Jobs                    3737.133369
# Storage                  392.935835

# %%
df.loc[df['Realm'] == 'Cloud']
# Out:
#                                               Test Name  Realm  \
# 0     Cloud/configuration/cloud_avg_cores_reserved/a...  Cloud
# 1     Cloud/configuration/cloud_avg_cores_reserved/a...  Cloud
# 2     Cloud/configuration/cloud_avg_cores_reserved/a...  Cloud
# 3     Cloud/configuration/cloud_avg_cores_reserved/a...  Cloud
# 4     Cloud/configuration/cloud_avg_cores_reserved/a...  Cloud
# ...                                                 ...    ...
# 5995  Cloud/vm_size_memory/cloud_wall_time/timeserie...  Cloud
# 5996  Cloud/vm_size_memory/cloud_wall_time/timeserie...  Cloud
# 5997  Cloud/vm_size_memory/cloud_wall_time/timeserie...  Cloud
# 5998  Cloud/vm_size_memory/cloud_wall_time/timeserie...  Cloud
# 5999  Cloud/vm_size_memory/cloud_wall_time/timeserie...  Cloud
#
#                 Type                  Artifact        Test Sub Test  \
# 0      configuration  cloud_avg_cores_reserved   aggregate      Day
# 1      configuration  cloud_avg_cores_reserved   aggregate      Day
# 2      configuration  cloud_avg_cores_reserved   aggregate      Day
# 3      configuration  cloud_avg_cores_reserved   aggregate      Day
# 4      configuration  cloud_avg_cores_reserved   aggregate      Day
# ...              ...                       ...         ...      ...
# 5995  vm_size_memory           cloud_wall_time  timeseries     Year
# 5996  vm_size_memory           cloud_wall_time  timeseries     Year
# 5997  vm_size_memory           cloud_wall_time  timeseries     Year
# 5998  vm_size_memory           cloud_wall_time  timeseries     Year
# 5999  vm_size_memory           cloud_wall_time  timeseries     Year
#
#       MyISAM Total Time  MyISAM Start Transfer Time  InnoDB Total Time  \
# 0              0.059955                    0.059950           0.056255
# 1              0.065416                    0.065412           0.061219
# 2              0.072476                    0.072471           0.065990
# 3              0.063708                    0.063705           0.056681
# 4              0.064494                    0.064490           0.062833
# ...                 ...                         ...                ...
# 5995           0.061283                    0.061279           0.065213
# 5996           0.065320                    0.065317           0.063308
# 5997           0.069700                    0.069697           0.068199
# 5998           0.063893                    0.063889           0.064779
# 5999           0.074316                    0.074312           0.065029
#
#       InnoDB Start Transfer Time
# 0                       0.056252
# 1                       0.061216
# 2                       0.065987
# 3                       0.056678
# 4                       0.062812
# ...                          ...
# 5995                    0.065210
# 5996                    0.063304
# 5997                    0.068194
# 5998                    0.064776
# 5999                    0.065026
#
# [6000 rows x 10 columns]

# %% [markdown]
# # Writing out Dataframes to local storage

# %%
df.to_csv('new_regression_timings.csv', index=False) #index=False avoids seperate column of indexes
per_df.to_csv('percentage_regression_timings.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f01a5b343dda> in <module>
# ----> 1 df.to_csv('new_regression_timings.csv', index=False) #index=False avoids seperate column of indexes
#       2 per_df.to_csv('percentage_regression_timings.csv', index=False)
#
# NameError: name 'df' is not defined
