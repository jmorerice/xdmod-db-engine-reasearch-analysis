# %% [markdown]
# # Reading Regression Timing Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set(rc = {'figure.figsize':(15,8)})
df = pd.read_csv('regression_timings master list.csv')
df
# Out:
#                                                Test Name  MyISAM Total Time  \
# 0      Cloud/configuration/cloud_avg_cores_reserved/a...           0.059955
# 1      Cloud/configuration/cloud_avg_cores_reserved/a...           0.065416
# 2      Cloud/configuration/cloud_avg_cores_reserved/a...           0.072476
# 3      Cloud/configuration/cloud_avg_cores_reserved/a...           0.063708
# 4      Cloud/configuration/cloud_avg_cores_reserved/a...           0.064494
# ...                                                  ...                ...
# 24395     Storage/username/user_count/timeseries-Year-cd           0.496918
# 24396     Storage/username/user_count/timeseries-Year-cs           0.495570
# 24397     Storage/username/user_count/timeseries-Year-pi           0.068550
# 24398  Storage/username/user_count/timeseries-Year-pu...           0.045511
# 24399    Storage/username/user_count/timeseries-Year-usr           0.071226
#
#        MyISAM Start Transfer Time  Unnamed: 3  InnoDB Total Time  \
# 0                        0.059950         NaN           0.056255
# 1                        0.065412         NaN           0.061219
# 2                        0.072471         NaN           0.065990
# 3                        0.063705         NaN           0.056681
# 4                        0.064490         NaN           0.062833
# ...                           ...         ...                ...
# 24395                    0.492954         NaN           0.244348
# 24396                    0.490856         NaN           0.261630
# 24397                    0.068547         NaN           0.062513
# 24398                    0.045504         NaN           0.048143
# 24399                    0.071222         NaN           0.068632
#
#        InnoDB Start Transfer Time
# 0                        0.056252
# 1                        0.061216
# 2                        0.065987
# 3                        0.056678
# 4                        0.062812
# ...                           ...
# 24395                    0.240255
# 24396                    0.256816
# 24397                    0.062508
# 24398                    0.048140
# 24399                    0.068628
#
# [24400 rows x 6 columns]

# %% [markdown]
# # Charting Total and Transfer Times

# %%
#df.sum() #sums all cols by default
cols_to_sum = ['MyISAM Total Time','MyISAM Start Transfer Time','InnoDB Total Time','InnoDB Start Transfer Time']
total_time = df[cols_to_sum].sum()
print(total_time)
plt.title("Regression Timings: MyISAM vs InnoDB")
#plt.bar(cols_to_sum, total_time)
plt.bar(cols_to_sum[0], total_time[0], color='blue', label='MyISAM')
plt.bar(cols_to_sum[2], total_time[2], color='red', label='InnoDB')
plt.bar(cols_to_sum[1], total_time[1], color='blue')
plt.bar(cols_to_sum[3], total_time[3], color='red')
plt.xticks(rotation=90) #rotate lables vertically
plt.xlabel('Database Timings')
plt.ylabel('Total Time Take (seconds)')
plt.legend()
plt.show()
# Out:
# MyISAM Total Time             8013.868693
# MyISAM Start Transfer Time    8004.468570
# InnoDB Total Time             4517.444272
# InnoDB Start Transfer Time    4508.897521
# dtype: float64

# %% [markdown]
# # Modifying Dataframe

# %% [markdown]
# ## Deleting & Inserting Additional Columns

# %%
del df['Unnamed: 3'] #Get rid of blank column, no need to rerun this whole block (errors)
test = df['Test Name'].str.split('/', expand=True)
l = test[3].str.split('-', expand=True)

df.insert(1, 'Realm', test[0])
df.insert(2, 'Group By', test[1])
df.insert(3, 'Statistic', test[2])
df.insert(4, 'Data Set Type', l[0])
df.insert(5, 'Aggregation Unit', l[1])
df
# Out:
#                                                Test Name    Realm  \
# 0      Cloud/configuration/cloud_avg_cores_reserved/a...    Cloud
# 1      Cloud/configuration/cloud_avg_cores_reserved/a...    Cloud
# 2      Cloud/configuration/cloud_avg_cores_reserved/a...    Cloud
# 3      Cloud/configuration/cloud_avg_cores_reserved/a...    Cloud
# 4      Cloud/configuration/cloud_avg_cores_reserved/a...    Cloud
# ...                                                  ...      ...
# 24395     Storage/username/user_count/timeseries-Year-cd  Storage
# 24396     Storage/username/user_count/timeseries-Year-cs  Storage
# 24397     Storage/username/user_count/timeseries-Year-pi  Storage
# 24398  Storage/username/user_count/timeseries-Year-pu...  Storage
# 24399    Storage/username/user_count/timeseries-Year-usr  Storage
#
#             Group By                 Statistic Data Set Type Aggregation Unit  \
# 0      configuration  cloud_avg_cores_reserved     aggregate              Day
# 1      configuration  cloud_avg_cores_reserved     aggregate              Day
# 2      configuration  cloud_avg_cores_reserved     aggregate              Day
# 3      configuration  cloud_avg_cores_reserved     aggregate              Day
# 4      configuration  cloud_avg_cores_reserved     aggregate              Day
# ...              ...                       ...           ...              ...
# 24395       username                user_count    timeseries             Year
# 24396       username                user_count    timeseries             Year
# 24397       username                user_count    timeseries             Year
# 24398       username                user_count    timeseries             Year
# 24399       username                user_count    timeseries             Year
#
#        MyISAM Total Time  MyISAM Start Transfer Time  InnoDB Total Time  \
# 0               0.059955                    0.059950           0.056255
# 1               0.065416                    0.065412           0.061219
# 2               0.072476                    0.072471           0.065990
# 3               0.063708                    0.063705           0.056681
# 4               0.064494                    0.064490           0.062833
# ...                  ...                         ...                ...
# 24395           0.496918                    0.492954           0.244348
# 24396           0.495570                    0.490856           0.261630
# 24397           0.068550                    0.068547           0.062513
# 24398           0.045511                    0.045504           0.048143
# 24399           0.071226                    0.071222           0.068632
#
#        InnoDB Start Transfer Time
# 0                        0.056252
# 1                        0.061216
# 2                        0.065987
# 3                        0.056678
# 4                        0.062812
# ...                           ...
# 24395                    0.240255
# 24396                    0.256816
# 24397                    0.062508
# 24398                    0.048140
# 24399                    0.068628
#
# [24400 rows x 10 columns]

# %% [markdown]
# # Further Analysis

# %% [markdown]
# ## Calculating Percentages Into A New Dataframe

# %%
percent_change = (100 * (df['InnoDB Total Time'] - df['MyISAM Total Time']) / df['MyISAM Total Time'].abs())
df.insert(10, 'Percent Change', percent_change)
df
# Out:
#                                                Test Name    Realm  \
# 0      Cloud/configuration/cloud_avg_cores_reserved/a...    Cloud
# 1      Cloud/configuration/cloud_avg_cores_reserved/a...    Cloud
# 2      Cloud/configuration/cloud_avg_cores_reserved/a...    Cloud
# 3      Cloud/configuration/cloud_avg_cores_reserved/a...    Cloud
# 4      Cloud/configuration/cloud_avg_cores_reserved/a...    Cloud
# ...                                                  ...      ...
# 24395     Storage/username/user_count/timeseries-Year-cd  Storage
# 24396     Storage/username/user_count/timeseries-Year-cs  Storage
# 24397     Storage/username/user_count/timeseries-Year-pi  Storage
# 24398  Storage/username/user_count/timeseries-Year-pu...  Storage
# 24399    Storage/username/user_count/timeseries-Year-usr  Storage
#
#             Group By                 Statistic Data Set Type Aggregation Unit  \
# 0      configuration  cloud_avg_cores_reserved     aggregate              Day
# 1      configuration  cloud_avg_cores_reserved     aggregate              Day
# 2      configuration  cloud_avg_cores_reserved     aggregate              Day
# 3      configuration  cloud_avg_cores_reserved     aggregate              Day
# 4      configuration  cloud_avg_cores_reserved     aggregate              Day
# ...              ...                       ...           ...              ...
# 24395       username                user_count    timeseries             Year
# 24396       username                user_count    timeseries             Year
# 24397       username                user_count    timeseries             Year
# 24398       username                user_count    timeseries             Year
# 24399       username                user_count    timeseries             Year
#
#        MyISAM Total Time  MyISAM Start Transfer Time  InnoDB Total Time  \
# 0               0.059955                    0.059950           0.056255
# 1               0.065416                    0.065412           0.061219
# 2               0.072476                    0.072471           0.065990
# 3               0.063708                    0.063705           0.056681
# 4               0.064494                    0.064490           0.062833
# ...                  ...                         ...                ...
# 24395           0.496918                    0.492954           0.244348
# 24396           0.495570                    0.490856           0.261630
# 24397           0.068550                    0.068547           0.062513
# 24398           0.045511                    0.045504           0.048143
# 24399           0.071226                    0.071222           0.068632
#
#        InnoDB Start Transfer Time  Percent Change
# 0                        0.056252       -6.171295
# 1                        0.061216       -6.415862
# 2                        0.065987       -8.949169
# 3                        0.056678      -11.030012
# 4                        0.062812       -2.575433
# ...                           ...             ...
# 24395                    0.240255      -50.827299
# 24396                    0.256816      -47.206247
# 24397                    0.062508       -8.806710
# 24398                    0.048140        5.783217
# 24399                    0.068628       -3.641929
#
# [24400 rows x 11 columns]

# %% [markdown]
# ## Scatter Plotting

# %%
sns.scatterplot(x=df.index, y=df['Percent Change'], hue=df['Realm'])
# Out:
# <AxesSubplot:ylabel='Percent Change'>

# %%
jobs_df = df.loc[df['Realm'] == 'Jobs']
sns.scatterplot(x=jobs_df.index, y=jobs_df['Percent Change'], hue=jobs_df['Group By'])
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# %% [markdown]
# ## Identifying Top Values for Percent Change

# %%
jobs_df.sort_values(by=['Percent Change'], ascending=False).head(5)
# Out:
#                                                Test Name Realm Group By  \
# 18277      Jobs/queue/total_cpu_hours/timeseries-Year-pi  Jobs    queue
# 18436  Jobs/queue/total_wallduration_hours/timeseries...  Jobs    queue
# 18399  Jobs/queue/total_waitduration_hours/timeseries...  Jobs    queue
# 18317      Jobs/queue/total_gpu_hours/timeseries-Year-pi  Jobs    queue
# 18397  Jobs/queue/total_waitduration_hours/timeseries...  Jobs    queue
#
#                       Statistic Data Set Type Aggregation Unit  \
# 18277           total_cpu_hours    timeseries             Year
# 18436  total_wallduration_hours    timeseries             Year
# 18399  total_waitduration_hours    timeseries             Year
# 18317           total_gpu_hours    timeseries             Year
# 18397  total_waitduration_hours    timeseries             Year
#
#        MyISAM Total Time  MyISAM Start Transfer Time  InnoDB Total Time  \
# 18277           1.371040                    1.371035           4.456244
# 18436           1.445229                    1.445224           4.517016
# 18399           1.434120                    1.434109           4.429914
# 18317           1.374653                    1.374650           4.232658
# 18397           1.374424                    1.374416           4.198843
#
#        InnoDB Start Transfer Time  Percent Change
# 18277                    4.456233      225.026549
# 18436                    4.517005      212.546731
# 18399                    4.429904      208.894235
# 18317                    4.232649      207.907377
# 18397                    4.198817      205.498376

# %% [markdown]
# ### Statistic Values (No Trend)

# %%
queue_jobs_df = jobs_df.loc[df['Group By'] == 'queue']
sns.scatterplot(x=queue_jobs_df.index, y=queue_jobs_df['Percent Change'], hue=queue_jobs_df['Statistic'])
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# %% [markdown]
# ### Aggregation Unit (Trend Found, Year)

# %%
sns.scatterplot(x=queue_jobs_df.index, y=queue_jobs_df['Percent Change'], hue=queue_jobs_df['Aggregation Unit'])
# Out:
# <AxesSubplot:ylabel='Percent Change'>

# %% [markdown]
# ### Testing with other Group By Values

# %%
nodecount_jobs_df = jobs_df.loc[df['Group By'] == 'nodecount']
sns.scatterplot(x=nodecount_jobs_df.index, y=nodecount_jobs_df['Percent Change'], hue=nodecount_jobs_df['Aggregation Unit'])
# Out:
# <AxesSubplot:ylabel='Percent Change'>

# %% [markdown]
# ## Nodecount trend found in Statistic, utilzation

# %%
sns.scatterplot(x=nodecount_jobs_df.index, y=nodecount_jobs_df['Percent Change'], hue=nodecount_jobs_df['Statistic'])
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# %%
username_jobs_df = jobs_df.loc[df['Group By'] == 'username']
sns.scatterplot(x=username_jobs_df.index, y=username_jobs_df['Percent Change'], hue=username_jobs_df['Statistic'])
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# %%
sns.scatterplot(x=username_jobs_df.index, y=username_jobs_df['Percent Change'], hue=username_jobs_df['Aggregation Unit'])
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)

# %% [markdown]
# # Writing Out Dataframes To Local Files

# %%
df.to_csv('new_regression_timings.csv', index=False) #index=False avoids seperate column of indexes
